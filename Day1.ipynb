# %% [markdown]
# <a href="https://colab.research.google.com/github/VaibhavPachpute21/Colab/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2
#   Downloading PyPDF2-2.2.0-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 14.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from PyPDF2) (4.2.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.2.0

# %%
import PyPDF2
data=open('/content/Introduction+to+natural+language+processing.pdf','rb')
reader=PyPDF2.PdfFileReader(data)
print(reader.numPages)
page=reader.getPage(2)
print(page.extractText())

textData=open('/content/demo.txt','r')
print(textData.read())
# Out:
# 41
# What is Natural language processing?
# Proprietary content. ©Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited
#
# NLP stands for natural language processing which is basically used to understand and interpret human
# language to the machine. In short it is the automatic way to manipulate the  natural language, like speech and
# text, by software for further analysis to get the required information from them
#
#
# hii this is demo

# %%
import pandas as pd
data=pd.read_csv('/content/jbs-data-1642853235722.csv')
data.head()
# Out:
# Index(['asset_name', 'email_id', 'response_date', 'response', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 1001', 'Unnamed: 1002', 'Unnamed: 1003', 'Unnamed: 1004',
#        'Unnamed: 1005', 'Unnamed: 1006', 'Unnamed: 1007', 'Unnamed: 1008',
#        'Unnamed: 1009', 'Unnamed: 1010'],
#       dtype='object', length=1011)

# %%
data.columns
# Out:
# Index(['asset_name', 'email_id', 'response_date', 'response', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 1001', 'Unnamed: 1002', 'Unnamed: 1003', 'Unnamed: 1004',
#        'Unnamed: 1005', 'Unnamed: 1006', 'Unnamed: 1007', 'Unnamed: 1008',
#        'Unnamed: 1009', 'Unnamed: 1010'],
#       dtype='object', length=1011)

# %%
data.shape
# Out:
# (437, 1011)

# %%
data.describe

# %%
data.isnull().sum()
# Out:
# asset_name         1
# email_id           0
# response_date     19
# response         209
# Unnamed: 4       266
#                 ...
# Unnamed: 1006    436
# Unnamed: 1007    436
# Unnamed: 1008    436
# Unnamed: 1009    436
# Unnamed: 1010    436
# Length: 1011, dtype: int64

# %%
data.isnull().any()
# Out:
# asset_name        True
# email_id         False
# response_date     True
# response          True
# Unnamed: 4        True
#                  ...
# Unnamed: 1006     True
# Unnamed: 1007     True
# Unnamed: 1008     True
# Unnamed: 1009     True
# Unnamed: 1010     True
# Length: 1011, dtype: bool

# %%
data_part=data.dropna()
data_part.isnull().sum()
# Out:
# asset_name       0
# email_id         0
# response_date    0
# response         0
# Unnamed: 4       0
#                 ..
# Unnamed: 1006    0
# Unnamed: 1007    0
# Unnamed: 1008    0
# Unnamed: 1009    0
# Unnamed: 1010    0
# Length: 1011, dtype: int64
